# %%
import torch
import torch.nn as nn
from torchsummary import summary
from lstm_dpcnn import *

# %%
class LSTM_DPCNN(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.lstm = nn.LSTM(input_size=256, hidden_size=128, num_layers=2, batch_first=True, bidirectional=True) # (b, seq_len, input_size) => (b, seq_len, hidden_size*2)
        self.dpcnn = DPCNN(1)
        self.linear = nn.Linear(512, 9)
        
    def forward(self, x):
        """
        each forward takes a 256 vector as input 
        """
        lstm_output, (_, _) = self.lstm(x) # (b, seq_len, hidden_size*2)
        lstm_output = torch.transpose(lstm_output, 2, 1) 
        lstm_output = lstm_output.view(lstm_output.shape[0], -1) # padding: (b, seq_len*hidden_size*2)
        dpcnn_output = self.dpcnn(x) # (b, 256)
        output = torch.cat((lstm_output, dpcnn_output), 1) #(b, seqlen*hidden_size*2+256) 
        output = self.linear(output)
        return output

# %%
model = LSTM_DPCNN()

# %%
example = torch.randn((3, 1, 256))

# %%
summary(model, example, device="cpu", depth=5)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [-1, 1, 256]              790,528
# ├─DPCNN: 1-2                             [-1, 256]                 --
# |    └─BasicBlock: 2-1                   [-1, 256, 256]            --
# |    |    └─ReLU: 3-1                    [-1, 1, 256]              --
# |    |    └─Conv1d: 3-2                  [-1, 256, 256]            1,024
# |    |    └─ReLU: 3-3                    [-1, 256, 256]            --
# |    |    └─Conv1d: 3-4                  [-1, 256, 256]            196,864
# |    |    └─Conv1d: 3-5                  [-1, 256, 256]            512
# |    └─Sequential: 2-2                   [-1, 256, 2]              --
# |    |    └─Sequential: 3-6              [-1, 256, 128]            --
# |    |    |    └─MaxPool1d: 4-1          [-1, 256, 128]            --
# |    |    |    └─BasicBlock: 4-2         [-1, 256, 128]            --
# |    |    |    |    └─ReLU: 5-1          [-1, 256, 128]            --
# |    |    |    |    └─Conv1d: 5-2        [-1, 256, 128]            196,864
# |    |    |    |    └─ReLU: 5-3          [-1, 256, 128]            --
# |    |    |    |    └─Conv1d: 5-4        [-1, 256, 128]            196,864
# |    |    └─Sequential: 3-7              [-1, 256, 64]             --
# |    |    |    └─MaxPool1d: 4-3          [-1, 256, 64]             --
# |    |    |    └─BasicBlock: 4-4         [-1, 256, 64]             --
# |    |    |    |    └─ReLU: 5-5          [-1, 256, 64]             --
# |    |    |    |    └─Conv1d: 5-6        [-1, 256, 64]             196,864
# |    |    |    |    └─ReLU: 5-7          [-1, 256, 64]             --
# |    |    |    |    └─Conv1d: 5-8        [-1, 256, 64]             196,864
# |    |    └─Sequential: 3-8              [-1, 256, 32]             --
# |    |    |    └─MaxPool1d: 4-5          [-1, 256, 32]             --
# |    |    |    └─BasicBlock: 4-6         [-1, 256, 32]             --
# |    |    |    |    └─ReLU: 5-9          [-1, 256, 32]             --
# |    |    |    |    └─Conv1d: 5-10       [-1, 256, 32]             196,864
# |    |    |    |    └─ReLU: 5-11         [-1, 256, 32]             --
# |    |    |    |    └─Conv1d: 5-12       [-1, 256, 32]             196,864
# |    |    └─Sequential: 3-9              [-1, 256, 16]             --
# |    |    |    └─MaxPool1d: 4-7          [-1, 256, 16]             --
# |    |    |    └─BasicBlock: 4-8         [-1, 256, 16]             --
# |    |    |    |    └─ReLU: 5-13         [-1, 256, 16]             --
# |    |    |    |    └─Conv1d: 5-14       [-1, 256, 16]             196,864
# |    |    |    |    └─ReLU: 5-15         [-1, 256, 16]             --
# |    |    |    |    └─Conv1d: 5-16       [-1, 256, 16]             196,864
# |    |    └─Sequential: 3-10             [-1, 256, 8]              --
# |    |    |    └─MaxPool1d: 4-9          [-1, 256, 8]              --
# |    |    |    └─BasicBlock: 4-10        [-1, 256, 8]              --
# |    |    |    |    └─ReLU: 5-17         [-1, 256, 8]              --
# |    |    |    |    └─Conv1d: 5-18       [-1, 256, 8]              196,864
# |    |    |    |    └─ReLU: 5-19         [-1, 256, 8]              --
# |    |    |    |    └─Conv1d: 5-20       [-1, 256, 8]              196,864
# |    |    └─Sequential: 3-11             [-1, 256, 4]              --
# |    |    |    └─MaxPool1d: 4-11         [-1, 256, 4]              --
# |    |    |    └─BasicBlock: 4-12        [-1, 256, 4]              --
# |    |    |    |    └─ReLU: 5-21         [-1, 256, 4]              --
# |    |    |    |    └─Conv1d: 5-22       [-1, 256, 4]              196,864
# |    |    |    |    └─ReLU: 5-23         [-1, 256, 4]              --
# |    |    |    |    └─Conv1d: 5-24       [-1, 256, 4]              196,864
# |    |    └─Sequential: 3-12             [-1, 256, 2]              --
# |    |    |    └─MaxPool1d: 4-13         [-1, 256, 2]              --
# |    |    |    └─BasicBlock: 4-14        [-1, 256, 2]              --
# |    |    |    |    └─ReLU: 5-25         [-1, 256, 2]              --
# |    |    |    |    └─Conv1d: 5-26       [-1, 256, 2]              196,864
# |    |    |    |    └─ReLU: 5-27         [-1, 256, 2]              --
# |    |    |    |    └─Conv1d: 5-28       [-1, 256, 2]              196,864
# |    └─AvgPool1d: 2-3                    [-1, 256, 1]              --
# ├─Linear: 1-3                            [-1, 9]                   4,617
# ==========================================================================================
# Total params: 3,749,641
# Trainable params: 3,749,641
# Non-trainable params: 0
# Total mult-adds (M): 164.50
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.49
# Params size (MB): 14.30
# Estimated Total Size (MB): 16.80
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [-1, 1, 256]              790,528
# ├─DPCNN: 1-2                             [-1, 256]                 --
# |    └─BasicBlock: 2-1                   [-1, 256, 256]            --
# |    |    └─ReLU: 3-1                    [-1, 1, 256]              --
# |    |    └─Conv1d: 3-2                  [-1, 256, 256]            1,024
# |    |    └─ReLU: 3-3                    [-1, 256, 256]            --
# |    |    └─Conv1d: 3-4                  [-1, 256, 256]            196,864
# |    |    └─Conv1d: 3-5                  [-1, 256, 256]            512
# |    └─Sequential: 2-2                   [-1, 256, 2]              --
# |    |    └─Sequential: 3-6              [-1, 256, 128]            --
# |    |    |    └─MaxPool1d: 4-1          [-1, 256, 128]            --
# |    |    |    └─BasicBlock: 4-2         [-1, 256, 128]            --
# |    |    |    |    └─ReLU: 5-1          [-1, 256, 128]            --
# |    |    |    |    └─Conv1d: 5-2        [-1, 256, 128]            196,864
# |    |    |    |    └─ReLU: 5-3          [-1, 256, 128]            --
# |    |    |    |    └─Conv1d: 5-4        [-1, 256, 128]            196,864
# |    |    └─Sequential: 3-7              [-1, 256, 64]             --
# |    |    |    └─MaxPool1d: 4-3          [-1, 256, 64]             --
# |    |    |    └─BasicBlock: 4-4         [-1, 256, 64]             --
# |    |    |    |    └─ReLU: 5-5          [-1, 256, 64]             --
# |    |    |    |    └─Conv1d: 5-6        [-1, 256, 64]             196,864
# |    |    |    |    └─ReLU: 5-7          [-1, 256, 64]             --
# |    |    |    |    └─Conv1d: 5-8        [-1, 256, 64]             196,864
# |    |    └─Sequential: 3-8              [-1, 256, 32]             --
# |    |    |    └─MaxPool1d: 4-5          [-1, 256, 32]             --
# |    |    |    └─BasicBlock: 4-6         [-1, 256, 32]             --
# |    |    |    |    └─ReLU: 5-9          [-1, 256, 32]             --
# |    |    |    |    └─Conv1d: 5-10       [-1, 256, 32]             196,864
# |    |    |    |    └─ReLU: 5-11         [-1, 256, 32]             --
# |    |    |    |    └─Conv1d: 5-12       [-1, 256, 32]             196,864
# |    |    └─Sequential: 3-9              [-1, 256, 16]             --
# |    |    |    └─MaxPool1d: 4-7          [-1, 256, 16]             --
# |    |    |    └─BasicBlock: 4-8         [-1, 256, 16]             --
# |    |    |    |    └─ReLU: 5-13         [-1, 256, 16]             --
# |    |    |    |    └─Conv1d: 5-14       [-1, 256, 16]             196,864
# |    |    |    |    └─ReLU: 5-15         [-1, 256, 16]             --
# |    |    |    |    └─Conv1d: 5-16       [-1, 256, 16]             196,864
# |    |    └─Sequential: 3-10             [-1, 256, 8]              --
# |    |    |    └─MaxPool1d: 4-9          [-1, 256, 8]              --
# |    |    |    └─BasicBlock: 4-10        [-1, 256, 8]              --
# |    |    |    |    └─ReLU: 5-17         [-1, 256, 8]              --
# |    |    |    |    └─Conv1d: 5-18       [-1, 256, 8]              196,864
# |    |    |    |    └─ReLU: 5-19         [-1, 256, 8]              --
# |    |    |    |    └─Conv1d: 5-20       [-1, 256, 8]              196,864
# |    |    └─Sequential: 3-11             [-1, 256, 4]              --
# |    |    |    └─MaxPool1d: 4-11         [-1, 256, 4]              --
# |    |    |    └─BasicBlock: 4-12        [-1, 256, 4]              --
# |    |    |    |    └─ReLU: 5-21         [-1, 256, 4]              --
# |    |    |    |    └─Conv1d: 5-22       [-1, 256, 4]              196,864
# |    |    |    |    └─ReLU: 5-23         [-1, 256, 4]              --
# |    |    |    |    └─Conv1d: 5-24       [-1, 256, 4]              196,864
# |    |    └─Sequential: 3-12             [-1, 256, 2]              --
# |    |    |    └─MaxPool1d: 4-13         [-1, 256, 2]              --
# |    |    |    └─BasicBlock: 4-14        [-1, 256, 2]              --
# |    |    |    |    └─ReLU: 5-25         [-1, 256, 2]              --
# |    |    |    |    └─Conv1d: 5-26       [-1, 256, 2]              196,864
# |    |    |    |    └─ReLU: 5-27         [-1, 256, 2]              --
# |    |    |    |    └─Conv1d: 5-28       [-1, 256, 2]              196,864
# |    └─AvgPool1d: 2-3                    [-1, 256, 1]              --
# ├─Linear: 1-3                            [-1, 9]                   4,617
# ==========================================================================================
# Total params: 3,749,641
# Trainable params: 3,749,641
# Non-trainable params: 0
# Total mult-adds (M): 164.50
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.49
# Params size (MB): 14.30
# Estimated Total Size (MB): 16.80
# ==========================================================================================
