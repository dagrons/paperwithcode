# %%
import torch
import torch.nn as nn
from torchsummary import summary

# %% [markdown]
# 参数解释：
# 1. output_channels决定了filter的个数，每个filter会产生一个channel
# 2. kernel_size决定了filter的形状
# 3. 如果要使input和ouput的大小一致，则kernel_size为奇数，且padding=kernel_size/2(下取整)，例如：kernel_size=3时，padding=kernel_size/2=1
# 4. conv3的目的是为了让identity的channels和x的channels保持一致
# 5. conv layer不对输入的图像大小做假设
# 6. nn.Sequential接受一个list of layers，返回他们串联的结果
# 7. nn.MaxPool1d(kernel_size=3, stride=2, padding=1), stride=2，则图像大小H和W应该为偶数，stride=2会造成图像缩小一半
# 8. nn.AvgPool1d(kernel_size=2, stride=1)会造成图像H-1,W-1
#
# 模型来源：https://ai.tencent.com/ailab/media/publications/ACL3-Brady.pdf

# %%
class BasicBlock(nn.Module):
    # 256 => 256
    def __init__(self, in_channels, out_channels):
        super().__init__()
        
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv1d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, padding=1) 
        self.conv2 = nn.Conv1d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, padding=1)
        self.conv3 = nn.Conv1d(in_channels=in_channels, out_channels=out_channels, kernel_size=1)
    
    def forward(self, x):
        identity = x
        
        out = self.relu(x)
        out = self.conv1(out)
        out = self.relu(out)
        out = self.conv2(out)
        
        if out.shape != identity.shape:
            identity = self.conv3(identity)
        
        return nn.ReLU()(out + identity)
    
class DPCNN(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        
        self.first_block = BasicBlock(in_channels, 256)
        self.repeat_blocks = self._generate_repeated_block(7)
        self.avg_pool = nn.AvgPool1d(kernel_size=2, stride=1)
        self.linear = nn.Linear(256, 9)
        
        # Kaiming He initialization
        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        
    @staticmethod
    def _generate_repeated_block(num):
        layers = []
        for i in range(num):
            repeat_block = nn.Sequential(
                nn.MaxPool1d(kernel_size=3, stride=2, padding=1),
                BasicBlock(in_channels=256, out_channels=256)
            )
            layers.append(repeat_block)
            
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = self.first_block(x)
        out = self.repeat_blocks(out)
        out = self.avg_pool(out)
        out = out.view(out.shape[0], -1) # padding
        out = self.linear(out)
        
        return out

# %%
model = DPCNN(in_channels=1)

# %%
model
# Out:
# DPCNN(
#   (first_block): BasicBlock(
#     (relu): ReLU()
#     (conv1): Conv1d(1, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv3): Conv1d(1, 256, kernel_size=(1,), stride=(1,))
#   )
#   (repeat_blocks): Sequential(
#     (0): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (1): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (2): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (3): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (4): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (5): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (6): Sequential(
#       (0): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): BasicBlock(
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (avg_pool): AvgPool1d(kernel_size=(2,), stride=(1,), padding=(0,))
#   (linear): Linear(in_features=256, out_features=9, bias=True)
# )

# %%
example = torch.randn((4, 1, 256))

# %%
model(example).shape
# Out:
# torch.Size([4, 9])

# %%
summary(model, example, device="cpu", depth=5)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─BasicBlock: 1-1                        [-1, 256, 256]            --
# |    └─ReLU: 2-1                         [-1, 1, 256]              --
# |    └─Conv1d: 2-2                       [-1, 256, 256]            1,024
# |    └─ReLU: 2-3                         [-1, 256, 256]            --
# |    └─Conv1d: 2-4                       [-1, 256, 256]            196,864
# |    └─Conv1d: 2-5                       [-1, 256, 256]            512
# ├─Sequential: 1-2                        [-1, 256, 2]              --
# |    └─Sequential: 2-6                   [-1, 256, 128]            --
# |    |    └─MaxPool1d: 3-1               [-1, 256, 128]            --
# |    |    └─BasicBlock: 3-2              [-1, 256, 128]            --
# |    |    |    └─ReLU: 4-1               [-1, 256, 128]            --
# |    |    |    └─Conv1d: 4-2             [-1, 256, 128]            196,864
# |    |    |    └─ReLU: 4-3               [-1, 256, 128]            --
# |    |    |    └─Conv1d: 4-4             [-1, 256, 128]            196,864
# |    └─Sequential: 2-7                   [-1, 256, 64]             --
# |    |    └─MaxPool1d: 3-3               [-1, 256, 64]             --
# |    |    └─BasicBlock: 3-4              [-1, 256, 64]             --
# |    |    |    └─ReLU: 4-5               [-1, 256, 64]             --
# |    |    |    └─Conv1d: 4-6             [-1, 256, 64]             196,864
# |    |    |    └─ReLU: 4-7               [-1, 256, 64]             --
# |    |    |    └─Conv1d: 4-8             [-1, 256, 64]             196,864
# |    └─Sequential: 2-8                   [-1, 256, 32]             --
# |    |    └─MaxPool1d: 3-5               [-1, 256, 32]             --
# |    |    └─BasicBlock: 3-6              [-1, 256, 32]             --
# |    |    |    └─ReLU: 4-9               [-1, 256, 32]             --
# |    |    |    └─Conv1d: 4-10            [-1, 256, 32]             196,864
# |    |    |    └─ReLU: 4-11              [-1, 256, 32]             --
# |    |    |    └─Conv1d: 4-12            [-1, 256, 32]             196,864
# |    └─Sequential: 2-9                   [-1, 256, 16]             --
# |    |    └─MaxPool1d: 3-7               [-1, 256, 16]             --
# |    |    └─BasicBlock: 3-8              [-1, 256, 16]             --
# |    |    |    └─ReLU: 4-13              [-1, 256, 16]             --
# |    |    |    └─Conv1d: 4-14            [-1, 256, 16]             196,864
# |    |    |    └─ReLU: 4-15              [-1, 256, 16]             --
# |    |    |    └─Conv1d: 4-16            [-1, 256, 16]             196,864
# |    └─Sequential: 2-10                  [-1, 256, 8]              --
# |    |    └─MaxPool1d: 3-9               [-1, 256, 8]              --
# |    |    └─BasicBlock: 3-10             [-1, 256, 8]              --
# |    |    |    └─ReLU: 4-17              [-1, 256, 8]              --
# |    |    |    └─Conv1d: 4-18            [-1, 256, 8]              196,864
# |    |    |    └─ReLU: 4-19              [-1, 256, 8]              --
# |    |    |    └─Conv1d: 4-20            [-1, 256, 8]              196,864
# |    └─Sequential: 2-11                  [-1, 256, 4]              --
# |    |    └─MaxPool1d: 3-11              [-1, 256, 4]              --
# |    |    └─BasicBlock: 3-12             [-1, 256, 4]              --
# |    |    |    └─ReLU: 4-21              [-1, 256, 4]              --
# |    |    |    └─Conv1d: 4-22            [-1, 256, 4]              196,864
# |    |    |    └─ReLU: 4-23              [-1, 256, 4]              --
# |    |    |    └─Conv1d: 4-24            [-1, 256, 4]              196,864
# |    └─Sequential: 2-12                  [-1, 256, 2]              --
# |    |    └─MaxPool1d: 3-13              [-1, 256, 2]              --
# |    |    └─BasicBlock: 3-14             [-1, 256, 2]              --
# |    |    |    └─ReLU: 4-25              [-1, 256, 2]              --
# |    |    |    └─Conv1d: 4-26            [-1, 256, 2]              196,864
# |    |    |    └─ReLU: 4-27              [-1, 256, 2]              --
# |    |    |    └─Conv1d: 4-28            [-1, 256, 2]              196,864
# ├─AvgPool1d: 1-3                         [-1, 256, 1]              --
# ├─Linear: 1-4                            [-1, 9]                   2,313
# ==========================================================================================
# Total params: 2,956,809
# Trainable params: 2,956,809
# Non-trainable params: 0
# Total mult-adds (M): 160.30
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.49
# Params size (MB): 11.28
# Estimated Total Size (MB): 13.78
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─BasicBlock: 1-1                        [-1, 256, 256]            --
# |    └─ReLU: 2-1                         [-1, 1, 256]              --
# |    └─Conv1d: 2-2                       [-1, 256, 256]            1,024
# |    └─ReLU: 2-3                         [-1, 256, 256]            --
# |    └─Conv1d: 2-4                       [-1, 256, 256]            196,864
# |    └─Conv1d: 2-5                       [-1, 256, 256]            512
# ├─Sequential: 1-2                        [-1, 256, 2]              --
# |    └─Sequential: 2-6                   [-1, 256, 128]            --
# |    |    └─MaxPool1d: 3-1               [-1, 256, 128]            --
# |    |    └─BasicBlock: 3-2              [-1, 256, 128]            --
# |    |    |    └─ReLU: 4-1               [-1, 256, 128]            --
# |    |    |    └─Conv1d: 4-2             [-1, 256, 128]            196,864
# |    |    |    └─ReLU: 4-3               [-1, 256, 128]            --
# |    |    |    └─Conv1d: 4-4             [-1, 256, 128]            196,864
# |    └─Sequential: 2-7                   [-1, 256, 64]             --
# |    |    └─MaxPool1d: 3-3               [-1, 256, 64]             --
# |    |    └─BasicBlock: 3-4              [-1, 256, 64]             --
# |    |    |    └─ReLU: 4-5               [-1, 256, 64]             --
# |    |    |    └─Conv1d: 4-6             [-1, 256, 64]             196,864
# |    |    |    └─ReLU: 4-7               [-1, 256, 64]             --
# |    |    |    └─Conv1d: 4-8             [-1, 256, 64]             196,864
# |    └─Sequential: 2-8                   [-1, 256, 32]             --
# |    |    └─MaxPool1d: 3-5               [-1, 256, 32]             --
# |    |    └─BasicBlock: 3-6              [-1, 256, 32]             --
# |    |    |    └─ReLU: 4-9               [-1, 256, 32]             --
# |    |    |    └─Conv1d: 4-10            [-1, 256, 32]             196,864
# |    |    |    └─ReLU: 4-11              [-1, 256, 32]             --
# |    |    |    └─Conv1d: 4-12            [-1, 256, 32]             196,864
# |    └─Sequential: 2-9                   [-1, 256, 16]             --
# |    |    └─MaxPool1d: 3-7               [-1, 256, 16]             --
# |    |    └─BasicBlock: 3-8              [-1, 256, 16]             --
# |    |    |    └─ReLU: 4-13              [-1, 256, 16]             --
# |    |    |    └─Conv1d: 4-14            [-1, 256, 16]             196,864
# |    |    |    └─ReLU: 4-15              [-1, 256, 16]             --
# |    |    |    └─Conv1d: 4-16            [-1, 256, 16]             196,864
# |    └─Sequential: 2-10                  [-1, 256, 8]              --
# |    |    └─MaxPool1d: 3-9               [-1, 256, 8]              --
# |    |    └─BasicBlock: 3-10             [-1, 256, 8]              --
# |    |    |    └─ReLU: 4-17              [-1, 256, 8]              --
# |    |    |    └─Conv1d: 4-18            [-1, 256, 8]              196,864
# |    |    |    └─ReLU: 4-19              [-1, 256, 8]              --
# |    |    |    └─Conv1d: 4-20            [-1, 256, 8]              196,864
# |    └─Sequential: 2-11                  [-1, 256, 4]              --
# |    |    └─MaxPool1d: 3-11              [-1, 256, 4]              --
# |    |    └─BasicBlock: 3-12             [-1, 256, 4]              --
# |    |    |    └─ReLU: 4-21              [-1, 256, 4]              --
# |    |    |    └─Conv1d: 4-22            [-1, 256, 4]              196,864
# |    |    |    └─ReLU: 4-23              [-1, 256, 4]              --
# |    |    |    └─Conv1d: 4-24            [-1, 256, 4]              196,864
# |    └─Sequential: 2-12                  [-1, 256, 2]              --
# |    |    └─MaxPool1d: 3-13              [-1, 256, 2]              --
# |    |    └─BasicBlock: 3-14             [-1, 256, 2]              --
# |    |    |    └─ReLU: 4-25              [-1, 256, 2]              --
# |    |    |    └─Conv1d: 4-26            [-1, 256, 2]              196,864
# |    |    |    └─ReLU: 4-27              [-1, 256, 2]              --
# |    |    |    └─Conv1d: 4-28            [-1, 256, 2]              196,864
# ├─AvgPool1d: 1-3                         [-1, 256, 1]              --
# ├─Linear: 1-4                            [-1, 9]                   2,313
# ==========================================================================================
# Total params: 2,956,809
# Trainable params: 2,956,809
# Non-trainable params: 0
# Total mult-adds (M): 160.30
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.49
# Params size (MB): 11.28
# Estimated Total Size (MB): 13.78
# ==========================================================================================

# %% [markdown]
# summary解释：
#
# 1. channels数不变，但输入经过每一层Basic block变小
